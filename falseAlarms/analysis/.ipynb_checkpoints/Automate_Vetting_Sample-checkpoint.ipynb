# %% [markdown]
# ## Tune Vetting metrics in Exovetter
#
# Create a small sample of known false positives and known true positives to tune your exovetter thresholds.
# Especially for SWEET and LPP and Modshift and Centroid.
# then see what is left.
# I'd say pick 100 unique searches randomly from the bright uncrowded set.

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import parmap  #This code lets me speed things up by doing archive callsin parallel
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#Using qlp
notransit_file = "/Users/smullally/Science/tess_false_alarms/vet_results/joe_mar_2021/first-dataset/qlp_noebplanets_tcesum.csv"
planet_file = "/Users/smullally/Science/tess_false_alarms/vet_results/joe_mar_2021/second-dataset/qlp_ebplanets_tcesum.csv"
col_names = ["tic","pn","sector","period","epoch","depth","dur","snr","disp","reason", "match"]
notransit_df = pd.read_csv(notransit_file, names=col_names)
planet_df = pd.read_csv(planet_file, names=col_names)

#Created using uncrowded_kepler_targets.py
targetdf = pd.read_csv("/Users/smullally/Science/tess_false_alarms/keplerTargets/target_selection/target_tic_contamination_20210528.txt")
print(len(targetdf))
targetdf = targetdf.drop_duplicates(subset=['ticid','sector', 'Tmag'])
print(len(targetdf))

#Uniqueid
notransit_df['uniqueid'] = list(map( lambda x, y : "%s-s%u" % (x, y), notransit_df['tic'], notransit_df['sector']))
planet_df['uniqueid'] = list(map( lambda x, y : "%s-s%u" % (x, y), planet_df['tic'], planet_df['sector']))
targetdf['uniqueid'] = list(map( lambda x, y : "TIC %s-s%u" % (x, y), targetdf['ticid'], targetdf['sector']))

#Merge target information into qlp TCEs.
notransit_tces = pd.merge(notransit_df, targetdf[['Tmag', 'Hmag', 'Vmag','contratio','aperture','uniqueid']], left_on="uniqueid", right_on="uniqueid", how="inner" )
planet_tces = pd.merge(planet_df, targetdf[['Tmag', 'Hmag', 'Vmag','contratio','aperture','uniqueid']], left_on="uniqueid", right_on="uniqueid", how="inner" )
# Out:
# 84989
# 84614

# %%
print(len(notransit_df), len(notransit_tces), len(targetdf))
print(len(np.unique(targetdf['uniqueid'])))
print(len(planet_df), len(planet_tces))
print(len(np.unique(notransit_df['uniqueid'])), len(np.unique(notransit_tces['uniqueid'])))
# Out:
# 112559 112559 84614
# 84614
# 6977 465
# 84058 84058

# %%
planet_tces[0:5]
# Out:
#              tic  pn  sector  period      epoch       depth   dur   snr  \
# 0  TIC 120103486   1      14  0.8367  1683.7704     342.494  14.0  0.26
# 1  TIC 120103486   1      26  1.1253  2011.1130     322.458  14.0  0.24
# 2  TIC 120251825   1      14  1.5098  1683.7183  748209.592   2.0  3.60
# 3  TIC 120251825   2      14  1.5098  1684.4683  767513.015   2.0  7.03
# 4  TIC 120251825   3      14  1.5091  1683.7183  278923.956   4.0  3.52
#
#     disp                                    reason  match           uniqueid  \
# 0   FAIL                         -LowSNR--NormLPP-    NaN  TIC 120103486-s14
# 1   FAIL                         -LowSNR--NormLPP-    NaN  TIC 120103486-s26
# 2   FAIL   -NormLPP--SWEETHalfPeriod-SWEETAtPeriod    NaN  TIC 120251825-s14
# 3   FAIL   -NormLPP--SWEETHalfPeriod-SWEETAtPeriod    NaN  TIC 120251825-s14
# 4   FAIL   -NormLPP--SWEETHalfPeriod-SWEETAtPeriod    NaN  TIC 120251825-s14
#
#       Tmag    Hmag    Vmag  contratio   aperture
# 0  12.2136  11.162  12.810   0.051763  29.503800
# 1  12.2136  11.162  12.810   0.051763  29.503800
# 2  12.9390  12.464  13.822   1.041497  17.093791
# 3  12.9390  12.464  13.822   1.041497  17.093791
# 4  12.9390  12.464  13.822   1.041497  17.093791

# %%
#Vetting code to create a light curve and then vet.

import exovetter.vetters as vet
import corazon as crz
import lightkurve as lk
from exovetter.tce import Tce
from exovetter import const 

def get_lk(tcedf, author = "qlp", mission = "TESS", size = 11):
    """Returns lc and tpf given a dataframe line"""
    
    ticid = tcedf['tic'][4:]
    sector = tcedf['sector']
    
    lc = crz.gen_lightcurve.hlsp(ticid, sector, author=author)
    tpf = lk.search_tesscut(f"TIC {ticid}", sector = sector).download(cutout_size = size)
    
    return lc, tpf

def make_tce(adf, offset = 0 * u.day):
    
    atce = Tce(period = adf['period'] * u.day,
               epoch = adf['epoch'] *u.day,
               epoch_offset = offset,
               duration=adf['dur'] * u.hr, 
               depth=adf['depth'] * const.ppm,
               snr = adf['snr'])
    
    return atce

def vet_tce(tce, lc, tpf, plot=False):
    """Pull up plots of the full and folded light curve.
        There are all plot from exovetter
    """
    
    results = []
    
    tc = vet.TransitPhaseCoverage()
    tpc = tc.run(tce,lc)
    results.append(tpc)
    
    lpp = vet.Lpp()
    lppvet = lpp.run(tce,lc)
    results.append(lppvet)
    
    try:
        mod = vet.ModShift()
        modshift = mod.run(tce, lc)
        if plot:
            modshift.plot()
        results.append(modshift)
    except:
        pass
    
    sweet = vet.Sweet()
    sweetvet = sweet.run(tce,lc)
    if plot:
        sweet.plot()
    results.append(sweetvet)
    cent = vet.Centroid()
    centout = cent.run(tce, tpf, plot=plot)
    results.append(centout)
    
    #oe = vet.OddEven()
    #oddeven = oe.run(tce,lc)
    #oe.plot()
    #results.append(oddeven)
    
    fold = vet.VizTransits(smooth=8, max_transits=5, transit_only=True)
    ntransits = fold.run(tce, lc, plot=plot)
    results.append(ntransits)
    
    
    return results

# %%
#Get N tces at random for testing
r = np.random.randint(0, len(notransit_tces), size = 100)
notransit_samp = notransit_tces.iloc[r]

# %%
def vet_get_results(tcedfrow, plot=False, offset=const.btjd):
    tcedf = tcedfrow[1]
    alc, atpf = get_lk(tcedf) 
    atce = make_tce(tcedf, offset=offset)
    results = vet_tce(atce, alc, atpf, plot=plot)
    
    tcevet = dict(tcedf)
    for r in results:
        for k in r.keys():
            if k[0:3] != "plo":  #Don't include plot data
                tcevet[k] = r[k]
    
    return tcevet

# %%
result = parmap.parmap(vet_get_results, notransit_samp.iterrows(),engine='multi')
# Out:
# [▶······················································································································] 0/100 (0 sec)
# WARN: Function vet_get_results on task ((71993, tic              TIC 271545651
# pn                           1
# sector                      14
# period                 10.7836
# epoch                 1686.401
# depth                 4152.996
# dur                        4.0
# snr                       2.08
# disp                      FAIL
# reason               -NormLPP-
# match                      NaN
# uniqueid     TIC 271545651-s14
# Tmag                   10.9898
# Hmag                     8.272
# Vmag                    13.495
# contratio                  NaN
# aperture             36.598426
# Name: 71993, dtype: object),)
#  failed with error: 'AssertionError('  File "/Users/smullally/Python_Code/lambda-tess-search/falseAlarms/analysis/parmap.py", line 209, in __call__\n    return self.func(*args, **kwargs)\n', '  File "<ipython-input-89-8fc06540a095>", line 5, in vet_get_results\n    results = vet_tce(atce, alc, atpf, plot=plot)\n', '  File "<ipython-input-13-27d24ed07d4d>", line 61, in vet_tce\n    centout = cent.run(tce, tpf, plot=plot)\n', '  File "/Users/smullally/Python_Code/exovetter-repos/official/exovetter/exovetter/vetters.py", line 492, in run\n    offset, signif, fig = cent.measure_centroid_shift(centroids, plot)\n', '  File "/Users/smullally/Python_Code/exovetter-repos/official/exovetter/exovetter/centroid/centroid.py", line 121, in measure_centroid_shift\n    dcol[~flags], drow[~flags])\n', '  File "/Users/smullally/Python_Code/exovetter-repos/official/exovetter/exovetter/centroid/covar.py", line 137, in compute_offset_and_signif\n    sma, smi = compute_eigen_vectors(col, row)\n', '  File "/Users/smullally/Python_Code/exovetter-repos/official/exovetter/exovetter/centroid/covar.py", line 207, in compute_eigen_vectors\n    assert np.all(np.isfinite(cov))\n')'
# [▶····················································································································] 1/100 (25 sec)
# [▬▶···················································································································] 2/100 (25 sec)
# [▬▬▶··················································································································] 3/100 (25 sec)
# WARN: Function vet_get_results on task ((66998, tic               TIC 270789950
# pn                            1
# sector                       14
# period                   1.1269
# epoch                 1684.2157
# depth                  1080.477
# dur                        14.0
# snr                        0.33
# disp                       FAIL
# reason        -LowSNR--NormLPP-
# match                       NaN
# uniqueid      TIC 270789950-s14
# Tmag                      12.77
# Hmag                     11.778
# Vmag                     13.322
# contratio              0.062087
# aperture              21.273354
# Name: 66998, dtype: object),)
#  failed with error: 'SearchError("Unable to download FFI cutout. Desired target coordinates may be too near the edge of the FFI.Error: File name in directory 'tess-s0014-2-4_293.911766_46.640423_11x11_astrocut.fits' and header b'tess-s0014-2-4_295.306205_45.706362_11x11_astrocut.fits' differ.", '  File "/Users/smullally/Python_Code/lambda-tess-search/falseAlarms/analysis/parmap.py", line 209, in __call__\n    return self.func(*args, **kwargs)\n', '  File "<ipython-input-89-8fc06540a095>", line 3, in vet_get_results\n    alc, atpf = get_lk(tcedf)\n', '  File "<ipython-input-13-27d24ed07d4d>", line 16, in get_lk\n    tpf = lk.search_tesscut(f"TIC {ticid}", sector = sector).download(cutout_size = size)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/utils.py", line 555, in wrapper\n    return f(*args, **kwargs)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 360, in download\n    **kwargs,\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 251, in _download_one\n    "Error: {}".format(exc)\n')'
# [▬▬▬▶·················································································································] 4/100 (25 sec)
# [▬▬▬▬▶················································································································] 5/100 (25 sec)
# WARN: Function vet_get_results on task ((76059, tic              TIC 272270744
# pn                           1
# sector                      14
# period                 10.2405
# epoch                1687.0301
# depth                 9850.395
# dur                        2.0
# snr                       2.25
# disp                      FAIL
# reason               -NormLPP-
# match                      NaN
# uniqueid     TIC 272270744-s14
# Tmag                   12.1252
# Hmag                    10.472
# Vmag                    13.119
# contratio                  NaN
# aperture             30.379318
# Name: 76059, dtype: object),)
#  failed with error: 'AssertionError('  File "/Users/smullally/Python_Code/lambda-tess-search/falseAlarms/analysis/parmap.py", line 209, in __call__\n    return self.func(*args, **kwargs)\n', '  File "<ipython-input-89-8fc06540a095>", line 5, in vet_get_results\n    results = vet_tce(atce, alc, atpf, plot=plot)\n', '  File "<ipython-input-13-27d24ed07d4d>", line 61, in vet_tce\n    centout = cent.run(tce, tpf, plot=plot)\n', '  File "/Users/smullally/Python_Code/exovetter-repos/official/exovetter/exovetter/vetters.py", line 492, in run\n    offset, signif, fig = cent.measure_centroid_shift(centroids, plot)\n', '  File "/Users/smullally/Python_Code/exovetter-repos/official/exovetter/exovetter/centroid/centroid.py", line 121, in measure_centroid_shift\n    dcol[~flags], drow[~flags])\n', '  File "/Users/smullally/Python_Code/exovetter-repos/official/exovetter/exovetter/centroid/covar.py", line 137, in compute_offset_and_signif\n    sma, smi = compute_eigen_vectors(col, row)\n', '  File "/Users/smullally/Python_Code/exovetter-repos/official/exovetter/exovetter/centroid/covar.py", line 207, in compute_eigen_vectors\n    assert np.all(np.isfinite(cov))\n')'
# [▬▬▬▬▬▬▶··············································································································] 6/100 (26 sec)
# [▬▬▬▬▬▬▬▶·············································································································] 7/100 (26 sec)
# WARN: Function vet_get_results on task ((77179, tic               TIC 272373045
# pn                            1
# sector                       14
# period                    0.956
# epoch                 1684.0675
# depth                   557.761
# dur                        14.0
# snr                        0.23
# disp                       FAIL
# reason        -LowSNR--NormLPP-
# match                       NaN
# uniqueid      TIC 272373045-s14
# Tmag                    12.3182
# Hmag                     11.458
# Vmag                     12.829
# contratio              0.358667
# aperture              28.351339
# Name: 77179, dtype: object),)
#  failed with error: 'SearchError("Unable to download FFI cutout. Desired target coordinates may be too near the edge of the FFI.Error: File name in directory 'tess-s0014-2-4_296.396852_43.314610_11x11_astrocut.fits' and header b'tess-s0026-2-4_282.199006_47.215706_11x11_astrocut.fits' differ.", '  File "/Users/smullally/Python_Code/lambda-tess-search/falseAlarms/analysis/parmap.py", line 209, in __call__\n    return self.func(*args, **kwargs)\n', '  File "<ipython-input-89-8fc06540a095>", line 3, in vet_get_results\n    alc, atpf = get_lk(tcedf)\n', '  File "<ipython-input-13-27d24ed07d4d>", line 16, in get_lk\n    tpf = lk.search_tesscut(f"TIC {ticid}", sector = sector).download(cutout_size = size)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/utils.py", line 555, in wrapper\n    return f(*args, **kwargs)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 360, in download\n    **kwargs,\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 251, in _download_one\n    "Error: {}".format(exc)\n')'
# [▬▬▬▬▬▬▬▬▶············································································································] 8/100 (26 sec)
# WARN: Function vet_get_results on task ((13266, tic                        TIC 123445638
# pn                                     1
# sector                                26
# period                           10.9175
# epoch                          2013.4707
# depth                           7554.996
# dur                                  2.0
# snr                                  4.2
# disp                                FAIL
# reason        -NormLPP--OddEvenDetected-
# match                                NaN
# uniqueid               TIC 123445638-s26
# Tmag                             12.1578
# Hmag                              10.558
# Vmag                              13.085
# contratio                            NaN
# aperture                       30.066202
# Name: 13266, dtype: object),)
#  failed with error: 'SearchError('Unable to download FFI cutout. Desired target coordinates may be too near the edge of the FFI.Error: File is not a zip file', '  File "/Users/smullally/Python_Code/lambda-tess-search/falseAlarms/analysis/parmap.py", line 209, in __call__\n    return self.func(*args, **kwargs)\n', '  File "<ipython-input-89-8fc06540a095>", line 3, in vet_get_results\n    alc, atpf = get_lk(tcedf)\n', '  File "<ipython-input-13-27d24ed07d4d>", line 16, in get_lk\n    tpf = lk.search_tesscut(f"TIC {ticid}", sector = sector).download(cutout_size = size)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/utils.py", line 555, in wrapper\n    return f(*args, **kwargs)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 360, in download\n    **kwargs,\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 251, in _download_one\n    "Error: {}".format(exc)\n')'
# [▬▬▬▬▬▬▬▬▬▶···········································································································] 9/100 (26 sec)
# WARN: Function vet_get_results on task ((97725, tic               TIC 350988920
# pn                            1
# sector                       26
# period                    0.866
# epoch                  2010.863
# depth                   558.895
# dur                        14.0
# snr                        0.33
# disp                       FAIL
# reason        -LowSNR--NormLPP-
# match                       NaN
# uniqueid      TIC 350988920-s26
# Tmag                    12.4307
# Hmag                     11.558
# Vmag                     13.003
# contratio              0.679829
# aperture              26.948508
# Name: 97725, dtype: object),)
#  failed with error: 'SearchError("Unable to download FFI cutout. Desired target coordinates may be too near the edge of the FFI.Error: File name in directory 'tess-s0026-2-4_283.709607_40.035761_11x11_astrocut.fits' and header b'tess-s0015-2-3_296.481875_44.009152_11x11_astrocut.fits' differ.", '  File "/Users/smullally/Python_Code/lambda-tess-search/falseAlarms/analysis/parmap.py", line 209, in __call__\n    return self.func(*args, **kwargs)\n', '  File "<ipython-input-89-8fc06540a095>", line 3, in vet_get_results\n    alc, atpf = get_lk(tcedf)\n', '  File "<ipython-input-13-27d24ed07d4d>", line 16, in get_lk\n    tpf = lk.search_tesscut(f"TIC {ticid}", sector = sector).download(cutout_size = size)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/utils.py", line 555, in wrapper\n    return f(*args, **kwargs)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 360, in download\n    **kwargs,\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 251, in _download_one\n    "Error: {}".format(exc)\n')'
# [▬▬▬▬▬▬▬▬▬▬▶·········································································································] 10/100 (26 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▶········································································································] 11/100 (27 sec)
# WARN: Function vet_get_results on task ((4840, tic              TIC 121085474
# pn                           1
# sector                      14
# period                 10.5012
# epoch                1686.0305
# depth                 1817.015
# dur                        4.0
# snr                       1.77
# disp                      FAIL
# reason               -NormLPP-
# match                      NaN
# uniqueid     TIC 121085474-s14
# Tmag                   11.0998
# Hmag                      9.72
# Vmag                    11.916
# contratio                  NaN
# aperture             36.272424
# Name: 4840, dtype: object),)
#  failed with error: 'SearchError("Unable to download FFI cutout. Desired target coordinates may be too near the edge of the FFI.Error: File name in directory 'tess-s0014-2-3_287.002302_38.867369_11x11_astrocut.fits' and header b'tess-s0014-2-4_295.306205_45.706362_11x11_astrocut.fits' differ.", '  File "/Users/smullally/Python_Code/lambda-tess-search/falseAlarms/analysis/parmap.py", line 209, in __call__\n    return self.func(*args, **kwargs)\n', '  File "<ipython-input-89-8fc06540a095>", line 3, in vet_get_results\n    alc, atpf = get_lk(tcedf)\n', '  File "<ipython-input-13-27d24ed07d4d>", line 16, in get_lk\n    tpf = lk.search_tesscut(f"TIC {ticid}", sector = sector).download(cutout_size = size)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/utils.py", line 555, in wrapper\n    return f(*args, **kwargs)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 360, in download\n    **kwargs,\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 251, in _download_one\n    "Error: {}".format(exc)\n')'
# [▬▬▬▬▬▬▬▬▬▬▬▬▶·······································································································] 12/100 (27 sec)
# WARN: Function vet_get_results on task ((90759, tic                TIC 27990260
# pn                            2
# sector                       14
# period                   0.8608
# epoch                 1683.8385
# depth                    173.13
# dur                        14.0
# snr                        0.22
# disp                       FAIL
# reason        -LowSNR--NormLPP-
# match                       NaN
# uniqueid       TIC 27990260-s14
# Tmag                    10.7668
# Hmag                      9.232
# Vmag                     12.138
# contratio                   NaN
# aperture              37.149551
# Name: 90759, dtype: object),)
#  failed with error: 'SearchError("Unable to download FFI cutout. Desired target coordinates may be too near the edge of the FFI.Error: File name in directory 'tess-s0014-2-4_296.963882_49.059339_11x11_astrocut.fits' and header b'tess-s0014-2-4_296.155033_43.892442_11x11_astrocut.fits' differ.", '  File "/Users/smullally/Python_Code/lambda-tess-search/falseAlarms/analysis/parmap.py", line 209, in __call__\n    return self.func(*args, **kwargs)\n', '  File "<ipython-input-89-8fc06540a095>", line 3, in vet_get_results\n    alc, atpf = get_lk(tcedf)\n', '  File "<ipython-input-13-27d24ed07d4d>", line 16, in get_lk\n    tpf = lk.search_tesscut(f"TIC {ticid}", sector = sector).download(cutout_size = size)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/utils.py", line 555, in wrapper\n    return f(*args, **kwargs)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 360, in download\n    **kwargs,\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 251, in _download_one\n    "Error: {}".format(exc)\n')'
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶·····································································································] 13/100 (27 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶····································································································] 14/100 (27 sec)
# WARN: Function vet_get_results on task ((34467, tic                                             TIC 159643407
# pn                                                          1
# sector                                                     14
# period                                                   0.97
# epoch                                               1683.7846
# depth                                                 639.956
# dur                                                       4.0
# snr                                                      0.41
# disp                                                     FAIL
# reason        -LowSNR--NormLPP--SWEETHalfPeriod-SWEETAtPeriod
# match                                                     NaN
# uniqueid                                    TIC 159643407-s14
# Tmag                                                   12.014
# Hmag                                                   10.923
# Vmag                                                    12.68
# contratio                                            0.179602
# aperture                                            31.368491
# Name: 34467, dtype: object),)
#  failed with error: 'SearchError("Unable to download FFI cutout. Desired target coordinates may be too near the edge of the FFI.Error: File name in directory 'tess-s0014-2-4_291.147650_47.716312_11x11_astrocut.fits' and header b'tess-s0026-2-4_283.709607_40.035761_11x11_astrocut.fits' differ.", '  File "/Users/smullally/Python_Code/lambda-tess-search/falseAlarms/analysis/parmap.py", line 209, in __call__\n    return self.func(*args, **kwargs)\n', '  File "<ipython-input-89-8fc06540a095>", line 3, in vet_get_results\n    alc, atpf = get_lk(tcedf)\n', '  File "<ipython-input-13-27d24ed07d4d>", line 16, in get_lk\n    tpf = lk.search_tesscut(f"TIC {ticid}", sector = sector).download(cutout_size = size)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/utils.py", line 555, in wrapper\n    return f(*args, **kwargs)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 360, in download\n    **kwargs,\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 251, in _download_one\n    "Error: {}".format(exc)\n')'
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶···································································································] 15/100 (27 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶··································································································] 16/100 (38 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶·································································································] 17/100 (38 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶································································································] 18/100 (39 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶······························································································] 19/100 (40 sec)
# WARN: Function vet_get_results on task ((66230, tic               TIC 270700252
# pn                            1
# sector                       15
# period                   0.8092
# epoch                  1711.737
# depth                   619.604
# dur                        14.0
# snr                        0.29
# disp                       FAIL
# reason        -LowSNR--NormLPP-
# match                       NaN
# uniqueid      TIC 270700252-s15
# Tmag                    12.4263
# Hmag                     11.442
# Vmag                     12.924
# contratio              0.394976
# aperture              27.006922
# Name: 66230, dtype: object),)
#  failed with error: 'SearchError("Unable to download FFI cutout. Desired target coordinates may be too near the edge of the FFI.Error: File name in directory 'tess-s0015-2-3_293.818131_45.201528_11x11_astrocut.fits' and header b'tess-s0014-1-2_289.517703_39.108886_11x11_astrocut.fits' differ.", '  File "/Users/smullally/Python_Code/lambda-tess-search/falseAlarms/analysis/parmap.py", line 209, in __call__\n    return self.func(*args, **kwargs)\n', '  File "<ipython-input-89-8fc06540a095>", line 3, in vet_get_results\n    alc, atpf = get_lk(tcedf)\n', '  File "<ipython-input-13-27d24ed07d4d>", line 16, in get_lk\n    tpf = lk.search_tesscut(f"TIC {ticid}", sector = sector).download(cutout_size = size)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/utils.py", line 555, in wrapper\n    return f(*args, **kwargs)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 360, in download\n    **kwargs,\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 251, in _download_one\n    "Error: {}".format(exc)\n')'
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶·····························································································] 20/100 (40 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶····························································································] 21/100 (42 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶···························································································] 22/100 (44 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶··························································································] 23/100 (51 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶·························································································] 24/100 (51 sec)
# WARN: Function vet_get_results on task ((87296, tic              TIC 275494052
# pn                           1
# sector                      14
# period                  9.6889
# epoch                1687.6115
# depth                 5604.208
# dur                        4.0
# snr                       2.26
# disp                      PASS
# reason
# match                      NaN
# uniqueid     TIC 275494052-s14
# Tmag                   11.5412
# Hmag                    10.068
# Vmag                     12.21
# contratio                  NaN
# aperture             34.486994
# Name: 87296, dtype: object),)
#  failed with error: 'SearchError("Unable to download FFI cutout. Desired target coordinates may be too near the edge of the FFI.Error: Bad CRC-32 for file 'tess-s0014-2-4_293.159379_43.325278_11x11_astrocut.fits'", '  File "/Users/smullally/Python_Code/lambda-tess-search/falseAlarms/analysis/parmap.py", line 209, in __call__\n    return self.func(*args, **kwargs)\n', '  File "<ipython-input-89-8fc06540a095>", line 3, in vet_get_results\n    alc, atpf = get_lk(tcedf)\n', '  File "<ipython-input-13-27d24ed07d4d>", line 16, in get_lk\n    tpf = lk.search_tesscut(f"TIC {ticid}", sector = sector).download(cutout_size = size)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/utils.py", line 555, in wrapper\n    return f(*args, **kwargs)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 360, in download\n    **kwargs,\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 251, in _download_one\n    "Error: {}".format(exc)\n')'
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶·······················································································] 25/100 (51 sec)
# WARN: Function vet_get_results on task ((16680, tic                         TIC 137545766
# pn                                      1
# sector                                 14
# period                             1.3622
# epoch                           1684.1093
# depth                            2046.429
# dur                                   4.0
# snr                                  1.37
# disp                                 FAIL
# reason        -NormLPP--SWEETTwicePeriod-
# match                                 NaN
# uniqueid                TIC 137545766-s14
# Tmag                              10.9357
# Hmag                               10.637
# Vmag                               11.113
# contratio                        0.124649
# aperture                        36.744784
# Name: 16680, dtype: object),)
#  failed with error: 'SearchError("Unable to download FFI cutout. Desired target coordinates may be too near the edge of the FFI.Error: File name in directory 'tess-s0014-1-2_292.333758_37.180009_11x11_astrocut.fits' and header b'tess-s0014-2-4_293.159379_43.325278_11x11_astrocut.fits' differ.", '  File "/Users/smullally/Python_Code/lambda-tess-search/falseAlarms/analysis/parmap.py", line 209, in __call__\n    return self.func(*args, **kwargs)\n', '  File "<ipython-input-89-8fc06540a095>", line 3, in vet_get_results\n    alc, atpf = get_lk(tcedf)\n', '  File "<ipython-input-13-27d24ed07d4d>", line 16, in get_lk\n    tpf = lk.search_tesscut(f"TIC {ticid}", sector = sector).download(cutout_size = size)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/utils.py", line 555, in wrapper\n    return f(*args, **kwargs)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 360, in download\n    **kwargs,\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 251, in _download_one\n    "Error: {}".format(exc)\n')'
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶······················································································] 26/100 (51 sec)
# WARN: Function vet_get_results on task ((38832, tic              TIC 164677483
# pn                           1
# sector                      14
# period                  8.2931
# epoch                1690.4475
# depth                 4297.524
# dur                        4.0
# snr                       1.25
# disp                      FAIL
# reason               -NormLPP-
# match                      NaN
# uniqueid     TIC 164677483-s14
# Tmag                   12.8053
# Hmag                    11.885
# Vmag                     13.33
# contratio             0.028077
# aperture             20.504678
# Name: 38832, dtype: object),)
#  failed with error: 'SearchError("Unable to download FFI cutout. Desired target coordinates may be too near the edge of the FFI.Error: File name in directory 'tess-s0014-2-3_284.286472_44.823531_11x11_astrocut.fits' and header b'tess-s0014-2-3_285.904107_44.584419_11x11_astrocut.fits' differ.", '  File "/Users/smullally/Python_Code/lambda-tess-search/falseAlarms/analysis/parmap.py", line 209, in __call__\n    return self.func(*args, **kwargs)\n', '  File "<ipython-input-89-8fc06540a095>", line 3, in vet_get_results\n    alc, atpf = get_lk(tcedf)\n', '  File "<ipython-input-13-27d24ed07d4d>", line 16, in get_lk\n    tpf = lk.search_tesscut(f"TIC {ticid}", sector = sector).download(cutout_size = size)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/utils.py", line 555, in wrapper\n    return f(*args, **kwargs)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 360, in download\n    **kwargs,\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 251, in _download_one\n    "Error: {}".format(exc)\n')'
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶·····················································································] 27/100 (51 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶····················································································] 28/100 (51 sec)
# WARN: Function vet_get_results on task ((21677, tic               TIC 158114501
# pn                            1
# sector                       14
# period                   0.9229
# epoch                 1684.0682
# depth                   216.752
# dur                        12.0
# snr                        0.27
# disp                       FAIL
# reason        -LowSNR--NormLPP-
# match                       NaN
# uniqueid      TIC 158114501-s14
# Tmag                    11.3825
# Hmag                     10.665
# Vmag                     11.505
# contratio              0.057975
# aperture              35.229072
# Name: 21677, dtype: object),)
#  failed with error: 'SearchError("Unable to download FFI cutout. Desired target coordinates may be too near the edge of the FFI.Error: Bad CRC-32 for file 'tess-s0014-2-3_285.904107_44.584419_11x11_astrocut.fits'", '  File "/Users/smullally/Python_Code/lambda-tess-search/falseAlarms/analysis/parmap.py", line 209, in __call__\n    return self.func(*args, **kwargs)\n', '  File "<ipython-input-89-8fc06540a095>", line 3, in vet_get_results\n    alc, atpf = get_lk(tcedf)\n', '  File "<ipython-input-13-27d24ed07d4d>", line 16, in get_lk\n    tpf = lk.search_tesscut(f"TIC {ticid}", sector = sector).download(cutout_size = size)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/utils.py", line 555, in wrapper\n    return f(*args, **kwargs)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 360, in download\n    **kwargs,\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 251, in _download_one\n    "Error: {}".format(exc)\n')'
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶···················································································] 29/100 (51 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶··················································································] 30/100 (51 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶·················································································] 31/100 (52 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶···············································································] 32/100 (52 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶··············································································] 33/100 (57 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶·············································································] 34/100 (57 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶············································································] 35/100 (57 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶···········································································] 36/100 (58 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶··········································································] 37/100 (63 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶········································································] 38/100 (63 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶·······································································] 39/100 (63 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶······································································] 40/100 (63 sec)
# WARN: Function vet_get_results on task ((19354, tic               TIC 138574755
# pn                            1
# sector                       14
# period                   0.8007
# epoch                 1683.6697
# depth                   692.802
# dur                        14.0
# snr                         0.3
# disp                       FAIL
# reason        -LowSNR--NormLPP-
# match                       NaN
# uniqueid      TIC 138574755-s14
# Tmag                    12.7772
# Hmag                     11.355
# Vmag                     13.479
# contratio                   NaN
# aperture              21.120217
# Name: 19354, dtype: object),)
#  failed with error: 'SearchError("Unable to download FFI cutout. Desired target coordinates may be too near the edge of the FFI.Error: File name in directory 'tess-s0014-1-1_294.146001_40.231379_11x11_astrocut.fits' and header b'tess-s0014-1-1_297.840931_39.693738_11x11_astrocut.fits' differ.", '  File "/Users/smullally/Python_Code/lambda-tess-search/falseAlarms/analysis/parmap.py", line 209, in __call__\n    return self.func(*args, **kwargs)\n', '  File "<ipython-input-89-8fc06540a095>", line 3, in vet_get_results\n    alc, atpf = get_lk(tcedf)\n', '  File "<ipython-input-13-27d24ed07d4d>", line 16, in get_lk\n    tpf = lk.search_tesscut(f"TIC {ticid}", sector = sector).download(cutout_size = size)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/utils.py", line 555, in wrapper\n    return f(*args, **kwargs)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 360, in download\n    **kwargs,\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 251, in _download_one\n    "Error: {}".format(exc)\n')'
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶·····································································] 41/100 (63 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶····································································] 42/100 (68 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶···································································] 43/100 (68 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶·································································] 44/100 (68 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶································································] 45/100 (69 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶·······························································] 46/100 (69 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶······························································] 47/100 (69 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶·····························································] 48/100 (79 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶····························································] 49/100 (79 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶··························································] 50/100 (79 sec)
# WARN: Function vet_get_results on task ((25820, tic              TIC 158487307
# pn                           1
# sector                      14
# period                  5.0894
# epoch                1686.6744
# depth                 1447.219
# dur                        1.0
# snr                       1.89
# disp                      FAIL
# reason               -NormLPP-
# match                      NaN
# uniqueid     TIC 158487307-s14
# Tmag                    11.501
# Hmag                     9.655
# Vmag                    12.637
# contratio                  NaN
# aperture             34.687065
# Name: 25820, dtype: object),)
#  failed with error: 'SearchError("Unable to download FFI cutout. Desired target coordinates may be too near the edge of the FFI.Error: File name in directory 'tess-s0014-2-3_287.485197_46.309153_11x11_astrocut.fits' and header b'tess-s0014-2-4_296.300818_45.697435_11x11_astrocut.fits' differ.", '  File "/Users/smullally/Python_Code/lambda-tess-search/falseAlarms/analysis/parmap.py", line 209, in __call__\n    return self.func(*args, **kwargs)\n', '  File "<ipython-input-89-8fc06540a095>", line 3, in vet_get_results\n    alc, atpf = get_lk(tcedf)\n', '  File "<ipython-input-13-27d24ed07d4d>", line 16, in get_lk\n    tpf = lk.search_tesscut(f"TIC {ticid}", sector = sector).download(cutout_size = size)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/utils.py", line 555, in wrapper\n    return f(*args, **kwargs)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 360, in download\n    **kwargs,\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 251, in _download_one\n    "Error: {}".format(exc)\n')'
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶·························································] 51/100 (79 sec)
# WARN: Function vet_get_results on task ((94984, tic              TIC 298969688
# pn                           2
# sector                      15
# period                  4.6509
# epoch                1711.9664
# depth                  3755.49
# dur                        2.0
# snr                        1.2
# disp                      FAIL
# reason               -NormLPP-
# match                      NaN
# uniqueid     TIC 298969688-s15
# Tmag                   12.8878
# Hmag                    12.169
# Vmag                    13.365
# contratio             0.081983
# aperture             18.508411
# Name: 94984, dtype: object),)
#  failed with error: 'SearchError("Unable to download FFI cutout. Desired target coordinates may be too near the edge of the FFI.Error: File name in directory 'tess-s0014-2-3_287.485197_46.309153_11x11_astrocut.fits' and header b'tess-s0014-2-4_296.300818_45.697435_11x11_astrocut.fits' differ.", '  File "/Users/smullally/Python_Code/lambda-tess-search/falseAlarms/analysis/parmap.py", line 209, in __call__\n    return self.func(*args, **kwargs)\n', '  File "<ipython-input-89-8fc06540a095>", line 3, in vet_get_results\n    alc, atpf = get_lk(tcedf)\n', '  File "<ipython-input-13-27d24ed07d4d>", line 16, in get_lk\n    tpf = lk.search_tesscut(f"TIC {ticid}", sector = sector).download(cutout_size = size)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/utils.py", line 555, in wrapper\n    return f(*args, **kwargs)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 360, in download\n    **kwargs,\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 251, in _download_one\n    "Error: {}".format(exc)\n')'
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶························································] 52/100 (79 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶·······················································] 53/100 (83 sec)
# WARN: Function vet_get_results on task ((90991, tic                                             TIC 279912828
# pn                                                          3
# sector                                                     26
# period                                                 1.1109
# epoch                                               2010.4625
# depth                                                 540.048
# dur                                                       8.0
# snr                                                      0.35
# disp                                                     FAIL
# reason        -LowSNR--NormLPP--SWEETHalfPeriod-SWEETAtPeriod
# match                                                     NaN
# uniqueid                                    TIC 279912828-s26
# Tmag                                                  11.9467
# Hmag                                                   10.672
# Vmag                                                   12.681
# contratio                                                 NaN
# aperture                                            31.912692
# Name: 90991, dtype: object),)
#  failed with error: 'SearchError("Unable to download FFI cutout. Desired target coordinates may be too near the edge of the FFI.Error: File name in directory 'tess-s0014-2-3_287.485197_46.309153_11x11_astrocut.fits' and header b'tess-s0014-2-4_296.300818_45.697435_11x11_astrocut.fits' differ.", '  File "/Users/smullally/Python_Code/lambda-tess-search/falseAlarms/analysis/parmap.py", line 209, in __call__\n    return self.func(*args, **kwargs)\n', '  File "<ipython-input-89-8fc06540a095>", line 3, in vet_get_results\n    alc, atpf = get_lk(tcedf)\n', '  File "<ipython-input-13-27d24ed07d4d>", line 16, in get_lk\n    tpf = lk.search_tesscut(f"TIC {ticid}", sector = sector).download(cutout_size = size)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/utils.py", line 555, in wrapper\n    return f(*args, **kwargs)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 360, in download\n    **kwargs,\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 251, in _download_one\n    "Error: {}".format(exc)\n')'
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶······················································] 54/100 (83 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶·····················································] 55/100 (83 sec)
# WARN: Function vet_get_results on task ((4906, tic               TIC 121109039
# pn                            1
# sector                       14
# period                   1.6064
# epoch                 1684.3743
# depth                   364.988
# dur                        14.0
# snr                        0.33
# disp                       FAIL
# reason        -LowSNR--NormLPP-
# match                       NaN
# uniqueid      TIC 121109039-s14
# Tmag                    11.8026
# Hmag                     10.267
# Vmag                     12.738
# contratio                   NaN
# aperture              32.955691
# Name: 4906, dtype: object),)
#  failed with error: 'SearchError("Unable to download FFI cutout. Desired target coordinates may be too near the edge of the FFI.Error: File name in directory 'tess-s0014-2-3_287.051250_40.324280_11x11_astrocut.fits' and header b'tess-s0014-2-4_288.260364_51.416268_11x11_astrocut.fits' differ.", '  File "/Users/smullally/Python_Code/lambda-tess-search/falseAlarms/analysis/parmap.py", line 209, in __call__\n    return self.func(*args, **kwargs)\n', '  File "<ipython-input-89-8fc06540a095>", line 3, in vet_get_results\n    alc, atpf = get_lk(tcedf)\n', '  File "<ipython-input-13-27d24ed07d4d>", line 16, in get_lk\n    tpf = lk.search_tesscut(f"TIC {ticid}", sector = sector).download(cutout_size = size)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/utils.py", line 555, in wrapper\n    return f(*args, **kwargs)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 360, in download\n    **kwargs,\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 251, in _download_one\n    "Error: {}".format(exc)\n')'
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶····················································] 56/100 (83 sec)
# WARN: Function vet_get_results on task ((107240, tic                TIC 48031100
# pn                            1
# sector                       26
# period                   0.9177
# epoch                 2010.7561
# depth                   113.935
# dur                        14.0
# snr                        0.29
# disp                       FAIL
# reason        -LowSNR--NormLPP-
# match                       NaN
# uniqueid       TIC 48031100-s26
# Tmag                     10.093
# Hmag                      9.405
# Vmag                     10.599
# contratio              0.007102
# aperture               38.24034
# Name: 107240, dtype: object),)
#  failed with error: 'SearchError("Unable to download FFI cutout. Desired target coordinates may be too near the edge of the FFI.Error: File name in directory 'tess-s0026-2-4_281.909328_48.179287_11x11_astrocut.fits' and header b'tess-s0015-2-3_298.149896_44.747800_11x11_astrocut.fits' differ.", '  File "/Users/smullally/Python_Code/lambda-tess-search/falseAlarms/analysis/parmap.py", line 209, in __call__\n    return self.func(*args, **kwargs)\n', '  File "<ipython-input-89-8fc06540a095>", line 3, in vet_get_results\n    alc, atpf = get_lk(tcedf)\n', '  File "<ipython-input-13-27d24ed07d4d>", line 16, in get_lk\n    tpf = lk.search_tesscut(f"TIC {ticid}", sector = sector).download(cutout_size = size)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/utils.py", line 555, in wrapper\n    return f(*args, **kwargs)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 360, in download\n    **kwargs,\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 251, in _download_one\n    "Error: {}".format(exc)\n')'
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶··················································] 57/100 (91 sec)
# WARN: Function vet_get_results on task ((47072, tic               TIC 171582813
# pn                            1
# sector                       14
# period                   0.8713
# epoch                 1683.7631
# depth                  1285.928
# dur                        14.0
# snr                        0.26
# disp                       FAIL
# reason        -LowSNR--NormLPP-
# match                       NaN
# uniqueid      TIC 171582813-s14
# Tmag                    12.9266
# Hmag                     12.002
# Vmag                     13.407
# contratio              0.245281
# aperture              17.451069
# Name: 47072, dtype: object),)
#  failed with error: 'SearchError("Unable to download FFI cutout. Desired target coordinates may be too near the edge of the FFI.Error: File name in directory 'tess-s0014-1-1_299.080188_40.592131_11x11_astrocut.fits' and header b'tess-s0014-2-4_288.260364_51.416268_11x11_astrocut.fits' differ.", '  File "/Users/smullally/Python_Code/lambda-tess-search/falseAlarms/analysis/parmap.py", line 209, in __call__\n    return self.func(*args, **kwargs)\n', '  File "<ipython-input-89-8fc06540a095>", line 3, in vet_get_results\n    alc, atpf = get_lk(tcedf)\n', '  File "<ipython-input-13-27d24ed07d4d>", line 16, in get_lk\n    tpf = lk.search_tesscut(f"TIC {ticid}", sector = sector).download(cutout_size = size)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/utils.py", line 555, in wrapper\n    return f(*args, **kwargs)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 360, in download\n    **kwargs,\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 251, in _download_one\n    "Error: {}".format(exc)\n')'
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶·················································] 58/100 (91 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶················································] 59/100 (91 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶···············································] 60/100 (91 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶··············································] 61/100 (91 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶·············································] 62/100 (91 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶···········································] 63/100 (95 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶··········································] 64/100 (98 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶·········································] 65/100 (98 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶········································] 66/100 (98 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶·······································] 67/100 (98 sec)
# ...
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶····································] 69/100 (98 sec)
# WARN: Function vet_get_results on task ((39065, tic                        TIC 164723837
# pn                                     1
# sector                                26
# period                           10.9621
# epoch                          2021.2019
# depth                           3148.989
# dur                                  2.0
# snr                                 4.94
# disp                                FAIL
# reason        -NormLPP--OddEvenDetected-
# match                                NaN
# uniqueid               TIC 164723837-s26
# Tmag                              8.2196
# Hmag                               8.072
# Vmag                               8.206
# contratio                       0.009438
# aperture                       42.635568
# Name: 39065, dtype: object),)
#  failed with error: 'SearchError("Unable to download FFI cutout. Desired target coordinates may be too near the edge of the FFI.Error: File name in directory 'tess-s0026-2-4_284.509963_47.419688_11x11_astrocut.fits' and header b'tess-s0014-1-2_292.222278_38.586616_11x11_astrocut.fits' differ.", '  File "/Users/smullally/Python_Code/lambda-tess-search/falseAlarms/analysis/parmap.py", line 209, in __call__\n    return self.func(*args, **kwargs)\n', '  File "<ipython-input-89-8fc06540a095>", line 3, in vet_get_results\n    alc, atpf = get_lk(tcedf)\n', '  File "<ipython-input-13-27d24ed07d4d>", line 16, in get_lk\n    tpf = lk.search_tesscut(f"TIC {ticid}", sector = sector).download(cutout_size = size)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/utils.py", line 555, in wrapper\n    return f(*args, **kwargs)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 360, in download\n    **kwargs,\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 251, in _download_one\n    "Error: {}".format(exc)\n')'
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶···································] 70/100 (99 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶··································] 71/100 (105 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶·································] 72/100 (105 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶································] 73/100 (105 sec)
# WARN: Function vet_get_results on task ((76888, tic                                             TIC 272363593
# pn                                                          1
# sector                                                     14
# period                                                 0.9668
# epoch                                               1683.8406
# depth                                                2427.683
# dur                                                       4.0
# snr                                                       0.6
# disp                                                     FAIL
# reason        -LowSNR--NormLPP--SWEETHalfPeriod-SWEETAtPeriod
# match                                                     NaN
# uniqueid                                    TIC 272363593-s14
# Tmag                                                  12.7493
# Hmag                                                   12.064
# Vmag                                                   13.191
# contratio                                            0.216728
# aperture                                            21.703811
# Name: 76888, dtype: object),)
#  failed with error: 'SearchError("Unable to download FFI cutout. Desired target coordinates may be too near the edge of the FFI.Error: File name in directory 'tess-s0014-2-4_296.459998_46.871560_11x11_astrocut.fits' and header b'tess-s0015-2-3_300.080226_44.478833_11x11_astrocut.fits' differ.", '  File "/Users/smullally/Python_Code/lambda-tess-search/falseAlarms/analysis/parmap.py", line 209, in __call__\n    return self.func(*args, **kwargs)\n', '  File "<ipython-input-89-8fc06540a095>", line 3, in vet_get_results\n    alc, atpf = get_lk(tcedf)\n', '  File "<ipython-input-13-27d24ed07d4d>", line 16, in get_lk\n    tpf = lk.search_tesscut(f"TIC {ticid}", sector = sector).download(cutout_size = size)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/utils.py", line 555, in wrapper\n    return f(*args, **kwargs)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 360, in download\n    **kwargs,\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 251, in _download_one\n    "Error: {}".format(exc)\n')'
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶······························] 74/100 (105 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶·····························] 75/100 (109 sec)
# WARN: Function vet_get_results on task ((53646, tic               TIC 239274456
# pn                            1
# sector                       15
# period                   0.9439
# epoch                 1711.8305
# depth                  1216.223
# dur                        14.0
# snr                        0.37
# disp                       FAIL
# reason        -LowSNR--NormLPP-
# match                       NaN
# uniqueid      TIC 239274456-s15
# Tmag                     12.362
# Hmag                      11.47
# Vmag                     12.912
# contratio               3.32381
# aperture               27.82684
# Name: 53646, dtype: object),)
#  failed with error: 'SearchError("Unable to download FFI cutout. Desired target coordinates may be too near the edge of the FFI.Error: File name in directory 'tess-s0014-2-4_296.459998_46.871560_11x11_astrocut.fits' and header b'tess-s0015-2-3_300.080226_44.478833_11x11_astrocut.fits' differ.", '  File "/Users/smullally/Python_Code/lambda-tess-search/falseAlarms/analysis/parmap.py", line 209, in __call__\n    return self.func(*args, **kwargs)\n', '  File "<ipython-input-89-8fc06540a095>", line 3, in vet_get_results\n    alc, atpf = get_lk(tcedf)\n', '  File "<ipython-input-13-27d24ed07d4d>", line 16, in get_lk\n    tpf = lk.search_tesscut(f"TIC {ticid}", sector = sector).download(cutout_size = size)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/utils.py", line 555, in wrapper\n    return f(*args, **kwargs)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 360, in download\n    **kwargs,\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 251, in _download_one\n    "Error: {}".format(exc)\n')'
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶····························] 76/100 (109 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶···························] 77/100 (119 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶··························] 78/100 (119 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶·························] 79/100 (119 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶·······················] 80/100 (119 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶······················] 81/100 (119 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶·····················] 82/100 (119 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶····················] 83/100 (119 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶···················] 84/100 (119 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶··················] 85/100 (121 sec)
# WARN: Function vet_get_results on task ((31457, tic               TIC 159106623
# pn                            1
# sector                       14
# period                   0.8796
# epoch                 1683.9909
# depth                   526.286
# dur                        14.0
# snr                        0.24
# disp                       FAIL
# reason        -LowSNR--NormLPP-
# match                       NaN
# uniqueid      TIC 159106623-s14
# Tmag                    12.6713
# Hmag                     11.702
# Vmag                     13.299
# contratio              0.092922
# aperture              23.207679
# Name: 31457, dtype: object),)
#  failed with error: 'SearchError("Unable to download FFI cutout. Desired target coordinates may be too near the edge of the FFI.Error: File name in directory 'tess-s0014-2-3_289.730413_44.048618_11x11_astrocut.fits' and header b'tess-s0014-1-1_297.695131_41.351187_11x11_astrocut.fits' differ.", '  File "/Users/smullally/Python_Code/lambda-tess-search/falseAlarms/analysis/parmap.py", line 209, in __call__\n    return self.func(*args, **kwargs)\n', '  File "<ipython-input-89-8fc06540a095>", line 3, in vet_get_results\n    alc, atpf = get_lk(tcedf)\n', '  File "<ipython-input-13-27d24ed07d4d>", line 16, in get_lk\n    tpf = lk.search_tesscut(f"TIC {ticid}", sector = sector).download(cutout_size = size)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/utils.py", line 555, in wrapper\n    return f(*args, **kwargs)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 360, in download\n    **kwargs,\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 251, in _download_one\n    "Error: {}".format(exc)\n')'
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶·················] 86/100 (121 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶···············] 87/100 (121 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶··············] 88/100 (122 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶·············] 89/100 (124 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶············] 90/100 (124 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶···········] 91/100 (124 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶··········] 92/100 (128 sec)
# WARN: Function vet_get_results on task ((94932, tic               TIC 298969286
# pn                            1
# sector                       26
# period                   0.8268
# epoch                 2010.5786
# depth                    83.924
# dur                        14.0
# snr                        0.25
# disp                       FAIL
# reason        -LowSNR--NormLPP-
# match                       NaN
# uniqueid      TIC 298969286-s26
# Tmag                     9.3982
# Hmag                      7.979
# Vmag                     10.289
# contratio                   NaN
# aperture              39.172396
# Name: 94932, dtype: object),)
#  failed with error: 'SearchError("Unable to download FFI cutout. Desired target coordinates may be too near the edge of the FFI.Error: File name in directory 'tess-s0026-2-1_288.428847_50.667077_11x11_astrocut.fits' and header b'tess-s0014-2-3_282.834235_40.892967_11x11_astrocut.fits' differ.", '  File "/Users/smullally/Python_Code/lambda-tess-search/falseAlarms/analysis/parmap.py", line 209, in __call__\n    return self.func(*args, **kwargs)\n', '  File "<ipython-input-89-8fc06540a095>", line 3, in vet_get_results\n    alc, atpf = get_lk(tcedf)\n', '  File "<ipython-input-13-27d24ed07d4d>", line 16, in get_lk\n    tpf = lk.search_tesscut(f"TIC {ticid}", sector = sector).download(cutout_size = size)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/utils.py", line 555, in wrapper\n    return f(*args, **kwargs)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 360, in download\n    **kwargs,\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 251, in _download_one\n    "Error: {}".format(exc)\n')'
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶·········] 93/100 (128 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶·······] 94/100 (131 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶······] 95/100 (134 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶·····] 96/100 (135 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶····] 97/100 (137 sec)
# WARN: Function vet_get_results on task ((40304, tic               TIC 164830410
# pn                            1
# sector                       26
# period                   0.9335
# epoch                 2010.5751
# depth                   219.407
# dur                        14.0
# snr                        0.29
# disp                       FAIL
# reason        -LowSNR--NormLPP-
# match                       NaN
# uniqueid      TIC 164830410-s26
# Tmag                    11.5829
# Hmag                      9.806
# Vmag                     12.629
# contratio                   NaN
# aperture              34.270201
# Name: 40304, dtype: object),)
#  failed with error: 'SearchError("Unable to download FFI cutout. Desired target coordinates may be too near the edge of the FFI.Error: File name in directory 'tess-s0026-2-4_284.949754_44.166037_11x11_astrocut.fits' and header b'tess-s0014-2-3_287.897450_40.995453_11x11_astrocut.fits' differ.", '  File "/Users/smullally/Python_Code/lambda-tess-search/falseAlarms/analysis/parmap.py", line 209, in __call__\n    return self.func(*args, **kwargs)\n', '  File "<ipython-input-89-8fc06540a095>", line 3, in vet_get_results\n    alc, atpf = get_lk(tcedf)\n', '  File "<ipython-input-13-27d24ed07d4d>", line 16, in get_lk\n    tpf = lk.search_tesscut(f"TIC {ticid}", sector = sector).download(cutout_size = size)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/utils.py", line 555, in wrapper\n    return f(*args, **kwargs)\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 360, in download\n    **kwargs,\n', '  File "/Users/smullally/miniconda3/envs/exovetter/lib/python3.7/site-packages/lightkurve/search.py", line 251, in _download_one\n    "Error: {}".format(exc)\n')'
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶···] 98/100 (137 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶··] 99/100 (137 sec)
# [▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▶] 100/100 (139 sec)

# %%
result[1]
# Out:
# {'tic': 'TIC 164461137',
#  'pn': 5,
#  'sector': 26,
#  'period': 4.2099,
#  'epoch': 2012.1753,
#  'depth': 15128.621,
#  'dur': 1.0,
#  'snr': 4.34,
#  'disp': ' FAIL',
#  'reason': ' -NormLPP--OddEvenDetected-',
#  'match': nan,
#  'uniqueid': 'TIC 164461137-s26',
#  'Tmag': 11.6168,
#  'Hmag': 9.616,
#  'Vmag': 12.841,
#  'contratio': nan,
#  'aperture': 34.08674149023658,
#  'transit_phase_coverage': 0.6,
#  'raw_lpp': 0.0073366644726370524,
#  'norm_lpp': 13.433389480735595,
#  'pri': 128,
#  'phase_pri': 1.333829702970297,
#  'sec': 117,
#  'phase_sec': 1.2254560396039604,
#  'ter': 280,
#  'phase_ter': 2.7135098019801984,
#  'pos': 23,
#  'phase_pos': 0.24592485148514853,
#  'sigma_pri': -525.0734197234093,
#  'sigma_sec': -514.5182333908285,
#  'sigma_ter': -394.5412359243955,
#  'sigma_pos': 248.86396171803548,
#  'false_alarm_threshold': 2.5793966979613265,
#  'Fred': 89.15891891841193,
#  'msg': 'OK: SWEET finds no out-of-transit variability at transit period',
#  'amp': array([[1.86894871e-04, 4.06739722e-04, 4.59495006e-01],
#         [7.51842128e-04, 4.06159207e-04, 1.85110202e+00],
#         [6.13893487e-05, 4.06774507e-04, 1.50917394e-01]]),
#  'offset': 1.4277515468218887,
#  'significance': array([0.96012672]),
#  'num_transits': 6}

# %%
new = list(filter(lambda x : x is not None, result))
vetted = pd.DataFrame(new)
vetted
# Out:
#               tic  pn  sector   period      epoch      depth   dur   snr  \
# 0   TIC 164461137   5      26   4.2099  2012.1753  15128.621   1.0  4.34
# 1   TIC 269357468   1      15   1.2439  1711.8097    877.586  12.0  0.28
# 2   TIC 270957565   4      14   5.6952  1685.0511   9030.911   1.0  1.65
# 3   TIC 158494625   1      14   0.8316  1683.6785    376.857  14.0  0.32
# 4   TIC 405688870   1      14   2.4067  1685.4454    761.018   1.0  1.38
# ..            ...  ..     ...      ...        ...        ...   ...   ...
# 66  TIC 268932656   1      14   0.9014  1683.9050    727.418  14.0  0.26
# 67  TIC 121939473   3      14   0.9145  1683.6971    770.877  14.0  0.33
# 68   TIC 27082218   1      14   0.9594  1683.6929    445.730  14.0  0.74
# 69  TIC 121461494   1      14  10.3153  1692.3826   8307.980   1.0  2.95
# 70   TIC 27774215   1      15  10.4418  1714.5453   4887.617   2.0  2.38
#
#      disp                                            reason  ...   sigma_sec  \
# 0    FAIL                        -NormLPP--OddEvenDetected-  ... -514.518233
# 1    FAIL                                 -LowSNR--NormLPP-  ...   61.812474
# 2    FAIL                                         -NormLPP-  ... -305.082153
# 3    FAIL                                 -LowSNR--NormLPP-  ...         NaN
# 4    FAIL                                         -NormLPP-  ... -291.656187
# ..    ...                                               ...  ...         ...
# 66   FAIL                                 -LowSNR--NormLPP-  ...         NaN
# 67   FAIL                                 -LowSNR--NormLPP-  ...         NaN
# 68   FAIL   -LowSNR--NormLPP--SWEETHalfPeriod-SWEETAtPeriod  ...         NaN
# 69   PASS                                                    ... -160.101165
# 70   FAIL                                         -NormLPP-  ...  -31.590791
#
#      sigma_ter   sigma_pos  false_alarm_threshold        Fred  \
# 0  -394.541236  248.863962               2.579397   89.158919
# 1    61.812474         NaN               0.838123    3.876176
# 2  -304.651913  481.011970               2.682103  101.849547
# 3          NaN         NaN                    NaN         NaN
# 4  -253.262406  139.584580               2.379997   66.765563
# ..         ...         ...                    ...         ...
# 66         NaN         NaN                    NaN         NaN
# 67         NaN         NaN                    NaN         NaN
# 68         NaN         NaN                    NaN         NaN
# 69 -155.723989  180.860696               2.875076   52.026458
# 70  -30.721085  191.899907               2.652883   54.881495
#
#                                                   msg  \
# 0   OK: SWEET finds no out-of-transit variability ...
# 1   OK: SWEET finds no out-of-transit variability ...
# 2   WARN: SWEET test finds signal at HALF transit ...
# 3   OK: SWEET finds no out-of-transit variability ...
# 4   WARN: SWEET test finds signal at TWICE the tra...
# ..                                                ...
# 66  OK: SWEET finds no out-of-transit variability ...
# 67  WARN: SWEET test finds signal at TWICE the tra...
# 68  WARN: SWEET test finds signal at HALF transit ...
# 69  WARN: SWEET test finds signal at the transit p...
# 70  WARN: SWEET test finds signal at HALF transit ...
#
#                                                   amp    offset  \
# 0   [[0.0001868948713819144, 0.000406739722416632,...  1.427752
# 1   [[0.00040348792605411155, 0.000258146727013416...  0.636482
# 2   [[0.0015772973193587947, 0.000318218980125741,...  1.475893
# 3   [[0.00014424940443777203, 0.000126880379398930...  2.661144
# 4   [[1.835194499491407e-05, 3.4987395764499944e-0...  0.277643
# ..                                                ...       ...
# 66  [[0.00014740180585191473, 0.000288924984105901...  0.864394
# 67  [[0.0016161219427288868, 0.0013746315783784108...  1.326393
# 68  [[0.0006739524913249718, 0.0001170288889957843...  0.718276
# 69  [[0.0003795738389467141, 0.0001486431855320705...  0.542055
# 70  [[0.0022337191963858988, 0.0004687436770015337...  2.525357
#
#             significance  num_transits
# 0   [0.9601267194386653]             6
# 1   [0.9863138483806643]            22
# 2   [0.5884293841529711]             4
# 3   [0.7827872909884903]            34
# 4   [0.9255633288773347]            11
# ..                   ...           ...
# 66  [0.9652535894835147]            31
# 67  [0.8387297323928226]            31
# 68  [0.8178328385075626]            29
# 69                 [nan]             2
# 70                 [nan]             3
#
# [71 rows x 39 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(vetted['period'],vetted['raw_lpp'], '.')
