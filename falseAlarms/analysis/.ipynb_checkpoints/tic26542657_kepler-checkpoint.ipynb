# %%
import lightkurve as lk

# %%
avail = lk.search_lightcurve('TIC 26542657')
avail
# Out:
# SearchResult containing 17 data products.
#
#  #       mission      year   author  exptime  target_name  distance
#                                         s                   arcsec
# --- ----------------- ---- --------- ------- ------------- --------
#   0 Kepler Quarter 04 2010    Kepler    1800 kplr012013550      0.0
#   1 Kepler Quarter 08 2011    Kepler    1800 kplr012013550      0.0
#   2 Kepler Quarter 11 2012    Kepler    1800 kplr012013550      0.0
#   3 Kepler Quarter 12 2012    Kepler    1800 kplr012013550      0.0
#   4 Kepler Quarter 15 2013    Kepler    1800 kplr012013550      0.0
#   5 Kepler Quarter 16 2013    Kepler    1800 kplr012013550      0.0
#   6    TESS Sector 14 2019      SPOC     120      26542657      0.0
#   7    TESS Sector 14 2019 TESS-SPOC    1800      26542657      0.0
#   8    TESS Sector 14 2019       QLP    1800      26542657      0.0
#   9    TESS Sector 14 2019       QLP    1800    1882992211      0.0
# ...

# %%
kepler15 = avail[4].download()

# %%
kepler15.plot()
# Out:
# <AxesSubplot:xlabel='Time - 2454833 [BKJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
kepler15flat = kepler15.flatten(window_length=2000)

# %%
kepler15per = kepler15flat.to_periodogram(method='lombscargle')
kepler15per.plot()
plt.xlim(0,2)
# Out:
# (0.0, 2.0)

# %%
kepler15per.period_at_max_power
kepler15flat.fold(kepler15per.period_at_max_power).plot()
# Out:
# <AxesSubplot:xlabel='Phase [JD]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
tess7lc = avail[7].download()
tess7lc.plot()
# Out:
# <AxesSubplot:xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
tess7flat = tess7lc.flatten(window_length=2001)
tess7flat.plot()
# Out:
# <AxesSubplot:xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
tess7per = tess7flat.to_periodogram(method="lombscargle")
tess7per.plot()
plt.xlim(0,2)
# Out:
# (0.0, 2.0)
